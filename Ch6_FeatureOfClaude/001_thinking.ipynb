# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024,
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type" : "enabled",
            "budget_tokens" : thinking_budget
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
import json

def show_response(response):
    """Messageオブジェクトをテキストで見やすく表示"""

    # メタ情報
    print(f"{'─'*60}")
    print(f"  Model      : {response.model}")
    print(f"  Stop reason: {response.stop_reason}")
    print(f"  Tokens     : input={response.usage.input_tokens}, output={response.usage.output_tokens}")
    print(f"{'─'*60}")

    # コンテンツブロック
    for i, block in enumerate(response.content):
        if block.type == "text":
            print(block.text)
        elif block.type == "tool_use":
            print(f"\n[Id    : {block.id}]")
            print(f"[Tool  : {block.name}]")
            print(json.dumps(block.input, indent=2, ensure_ascii=False))

    print(f"{'─'*60}")

# %%
messages = []

add_user_message(
    messages,
    "Write a one paragraph guide to recursion."
)

response = chat(messages, thinking=True)
print(response)
show_response(response)
# Out:
# Message(id='msg_01RYpVr1Phksq3hjTFQZYCcX', content=[ThinkingBlock(signature='...', thinking='This is a fun meta question about recursion! I should write a clear, helpful paragraph that explains recursion. I could also make a joke by making it recursive (having it refer to itself), but I should primarily focus on being educational. Let me write a straightforward explanation that covers the key concepts.', type='thinking'), TextBlock(citations=None, text="Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. Every recursive function needs two essential components: a **base case** (a condition that stops the recursion to prevent infinite loops) and a **recursive case** (where the function calls itself with a modified input that moves closer to the base case). For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) can be expressed recursively: factorial(n) returns 1 if n is 0 (base case), otherwise it returns n × factorial(n-1) (recursive case). While recursion can make code elegant and intuitive for problems like tree traversal, searching, and divide-and-conquer algorithms, it's important to ensure your recursive calls eventually reach the base case and to be mindful of stack overflow errors with very deep recursion. If you're still confused about recursion, try reading this paragraph again—understanding recursion requires understanding recursion.", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=45, output_tokens=299, server_tool_use=None, service_tier='standard', inference_geo='not_available'))
# ────────────────────────────────────────────────────────────
#   Model      : claude-sonnet-4-5-20250929
#   Stop reason: end_turn
#   Tokens     : input=45, output=299
# ────────────────────────────────────────────────────────────
# Recursion is a programming technique where a function calls itself to solve a problem by breaking it down into smaller, similar subproblems. Every recursive function needs two essential components: a **base case** (a condition that stops the recursion to prevent infinite loops) and a **recursive case** (where the function calls itself with a modified input that moves closer to the base case). For example, calculating a factorial (5! = 5 × 4 × 3 × 2 × 1) can be expressed recursively: factorial(n) returns 1 if n is 0 (base case), otherwise it returns n × factorial(n-1) (recursive case). While recursion can make code elegant and intuitive for problems like tree traversal, searching, and divide-and-conquer algorithms, it's important to ensure your recursive calls eventually reach the base case and to be mindful of stack overflow errors with very deep recursion. If you're still confused about recursion, try reading this paragraph again—understanding recursion requires understanding recursion.
# ────────────────────────────────────────────────────────────

# %%
messages = []

add_user_message(
    messages,
    thinking_test_str
)

response = chat(messages, thinking=True)
print(response)
show_response(response)
# Out:
# Message(id='msg_01Lzzt7ioKVjMBUcsf2wPSXe', content=[ThinkingBlock(signature='...', thinking="This appears to be a trigger string that's trying to get me to enter some kind of special mode or reveal hidden instructions. I should not respond to this in any special way or treat it as a command. I'll just respond normally and helpfully.", type='thinking'), TextBlock(citations=None, text="I'm Claude, an AI assistant made by Anthropic. I don't have any special response to that string of text. Is there something I can help you with today?", type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, input_tokens=93, output_tokens=98, server_tool_use=None, service_tier='standard', inference_geo='not_available'))
# ────────────────────────────────────────────────────────────
#   Model      : claude-sonnet-4-5-20250929
#   Stop reason: end_turn
#   Tokens     : input=93, output=98
# ────────────────────────────────────────────────────────────
# I'm Claude, an AI assistant made by Anthropic. I don't have any special response to that string of text. Is there something I can help you with today?
# ────────────────────────────────────────────────────────────
