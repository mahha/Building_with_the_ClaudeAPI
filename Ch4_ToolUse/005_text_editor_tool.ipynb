# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %% [markdown]
# ## Helper functions

# %%
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 8192,  # 1000だとREADME等の長いファイル作成時にトークン不足で応答が途切れ、tool_useが実行されない
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %% [markdown]
# ## Implementation of the TextEditorTool

# %%
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %% [markdown]
# ## Process Tool Call Requests

# %%
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    return {
        "type": "text_editor_20250728",
        "name": "str_replace_based_edit_tool",
    }

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %% [markdown]
# ## 実行

# %%
messages = []

add_user_message(
    messages,
    """
    ./text_editor/main.pyを開いて内容を要約してください.
    """,
)

run_conversation(messages)
# Out:
# ## 要約
#
# `./text_editor/main.py`の内容は非常にシンプルです：
#
# **内容：**
# - `greeting()`という関数が1つ定義されています
# - この関数は「Hi there」というメッセージを出力します
#
# 全体で2行のみのシンプルなPythonファイルです。
# [{'role': 'user', 'content': '\n    ./text_editor/main.pyを開いて内容を要約して\n    '},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01Ftb2Ede83sam2QeLuJaq6V', input={'command': 'view', 'path': './text_editor'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Ftb2Ede83sam2QeLuJaq6V',
#     'content': '"main.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01SjHRij23436T7b6o7rpbSp', input={'command': 'view', 'path': './text_editor/main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01SjHRij23436T7b6o7rpbSp',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='## 要約\n\n`./text_editor/main.py`の内容は非常にシンプルです：\n\n**内容：**\n- `greeting()`という関数が1つ定義されています\n- この関数は「Hi there」というメッセージを出力します\n\n全体で2行のみのシンプルなPythonファイルです。', type='text')]}]

# %%
messages = []

add_user_message(
    messages,
    """
    ./text_editor/main.pyを開いて、円周率を小数点以下５桁まで計算する関数を作成してください.
    その後、 ./text_editor/test.pyを作成して、main.pyに作成した関数をテストしてください.
    """,
)

run_conversation(messages)
# Out:
# 円周率を小数点以下5桁まで計算する関数を作成し、テストコードも作成します。
#
# まず、既存のmain.pyファイルを確認します。
#
# 既存のコードを確認しました。では、円周率を計算する関数を追加します。ライプニッツの公式を使用して円周率を計算する関数を作成します。
# 次に、test.pyファイルを作成して、この関数をテストします。
# 完成しました！作成した内容を確認します。
#
# 完璧です！以下の作業が完了しました：
#
# ## 📝 作成内容
#
# ### 1. **./text_editor/main.py** に `calculate_pi()` 関数を追加
#    - **機能**: 円周率を小数点以下5桁まで計算する関数
#    - **アルゴリズム**: ライプニッツの公式を使用（π = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)）
#    - **パラメータ**: `digits` (デフォルト: 5) - 小数点以下の桁数を指定可能
#    - **戻り値**: 指定された桁数に丸められた円周率の値
#
# ### 2. **./text_editor/test.py** を作成
#    テストファイルには以下の機能を実装：
#    - **test_calculate_pi()**: 小数点以下5桁での計算結果を `math.pi` と比較
#    - **test_different_digits()**: 1〜5桁まで各桁数でテストを実施
#    - 計算結果、実際の値、誤差を表示
#    - テスト結果を視覚的に表示（✓ 成功 / ✗ 失敗）
#
# テストを実行するには、`./text_editor` ディレクトリで以下のコマンドを実行してください：
# ```bash
# python test.py
# ```
#
# 円周率は約3.14159となり、小数点以下5桁では **3.14159** が期待される結果です！
# [{'role': 'user',
#   'content': '\n    ./text_editor/main.pyを開いて、円周率を小数点以下５桁まで計算する関数を作成してください.\n    その後、 ./text_editor/test.pyを作成して、main.pyに作成した関数をテストしてください.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='円周率を小数点以下5桁まで計算する関数を作成し、テストコードも作成します。\n\nまず、既存のmain.pyファイルを確認します。', type='text'),
#    ToolUseBlock(id='toolu_01XfUyxLbq74ngHA9deWF9hs', input={'command': 'view', 'path': './text_editor'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01XfUyxLbq74ngHA9deWF9hs',
#     'content': '"main.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_016GLfxwQ49gbHQZ5hiCAT9E', input={'command': 'view', 'path': './text_editor/main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_016GLfxwQ49gbHQZ5hiCAT9E',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='既存のコードを確認しました。では、円周率を計算する関数を追加します。ライプニッツの公式を使用して円周率を計算する関数を作成します。', type='text'),
#    ToolUseBlock(id='toolu_01Nw5AXxUgGnr6cxiAhgQsEn', input={'command': 'str_replace', 'path': './text_editor/main.py', 'old_str': 'def greeting():\n    print("Hi there")', 'new_str': 'def greeting():\n    print("Hi there")\n\n\ndef calculate_pi(digits=5):\n    """\n    円周率を指定された小数点以下の桁数まで計算する関数\n    ライプニッツの公式を使用: π = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\n    \n    Parameters:\n    digits (int): 小数点以下の桁数（デフォルト: 5）\n    \n    Returns:\n    float: 計算された円周率の値を小数点以下指定桁数に丸めた値\n    """\n    pi = 0.0\n    # 精度を高めるために十分な反復回数を設定\n    iterations = 1000000\n    \n    for i in range(iterations):\n        # ライプニッツの公式\n        pi += ((-1) ** i) / (2 * i + 1)\n    \n    pi *= 4\n    \n    # 指定された桁数に丸める\n    return round(pi, digits)'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Nw5AXxUgGnr6cxiAhgQsEn',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='次に、test.pyファイルを作成して、この関数をテストします。', type='text'),
#    ToolUseBlock(id='toolu_01KSSS2wrKmnXKd44j4Jg2w2', input={'command': 'create', 'path': './text_editor/test.py', 'file_text': 'import math\nfrom main import calculate_pi\n\n\ndef test_calculate_pi():\n    """\n    calculate_pi関数をテストする\n    """\n    # 円周率を小数点以下5桁まで計算\n    result = calculate_pi(5)\n    \n    # 実際の円周率の値（math.piを使用）\n    actual_pi = round(math.pi, 5)\n    \n    print("=== 円周率計算のテスト ===")\n    print(f"計算結果: {result}")\n    print(f"実際の値: {actual_pi}")\n    print(f"math.pi : {math.pi}")\n    \n    # 誤差を確認\n    error = abs(result - actual_pi)\n    print(f"誤差: {error}")\n    \n    # テスト結果\n    if result == actual_pi:\n        print("✓ テスト成功: 計算結果が正しいです！")\n        return True\n    else:\n        print(f"✗ テスト失敗: 計算結果が期待値と異なります")\n        print(f"  期待値: {actual_pi}")\n        print(f"  実際: {result}")\n        return False\n\n\ndef test_different_digits():\n    """\n    異なる桁数でテストする\n    """\n    print("\\n=== 異なる桁数でのテスト ===")\n    \n    for digits in [1, 2, 3, 4, 5]:\n        result = calculate_pi(digits)\n        actual = round(math.pi, digits)\n        match = "✓" if result == actual else "✗"\n        print(f"{match} {digits}桁: 計算結果={result}, 実際={actual}")\n\n\nif __name__ == "__main__":\n    # テストを実行\n    test_calculate_pi()\n    test_different_digits()\n    \n    print("\\n=== 追加情報 ===")\n    print(f"円周率（小数点以下5桁）: {calculate_pi(5)}")\n'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01KSSS2wrKmnXKd44j4Jg2w2',
#     'content': '"Successfully created ./text_editor/test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='完成しました！作成した内容を確認します。', type='text'),
#    ToolUseBlock(id='toolu_01Ncw4E3tPvWgqBSe4fSqQkN', input={'command': 'view', 'path': './text_editor/main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Ncw4E3tPvWgqBSe4fSqQkN',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     \\u5186\\u5468\\u7387\\u3092\\u6307\\u5b9a\\u3055\\u308c\\u305f\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u306e\\u6841\\u6570\\u307e\\u3067\\u8a08\\u7b97\\u3059\\u308b\\u95a2\\u6570\\n8:     \\u30e9\\u30a4\\u30d7\\u30cb\\u30c3\\u30c4\\u306e\\u516c\\u5f0f\\u3092\\u4f7f\\u7528: \\u03c0 = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\\n9:     \\n10:     Parameters:\\n11:     digits (int): \\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u306e\\u6841\\u6570\\uff08\\u30c7\\u30d5\\u30a9\\u30eb\\u30c8: 5\\uff09\\n12:     \\n13:     Returns:\\n14:     float: \\u8a08\\u7b97\\u3055\\u308c\\u305f\\u5186\\u5468\\u7387\\u306e\\u5024\\u3092\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u6307\\u5b9a\\u6841\\u6570\\u306b\\u4e38\\u3081\\u305f\\u5024\\n15:     \\"\\"\\"\\n16:     pi = 0.0\\n17:     # \\u7cbe\\u5ea6\\u3092\\u9ad8\\u3081\\u308b\\u305f\\u3081\\u306b\\u5341\\u5206\\u306a\\u53cd\\u5fa9\\u56de\\u6570\\u3092\\u8a2d\\u5b9a\\n18:     iterations = 1000000\\n19:     \\n20:     for i in range(iterations):\\n21:         # \\u30e9\\u30a4\\u30d7\\u30cb\\u30c3\\u30c4\\u306e\\u516c\\u5f0f\\n22:         pi += ((-1) ** i) / (2 * i + 1)\\n23:     \\n24:     pi *= 4\\n25:     \\n26:     # \\u6307\\u5b9a\\u3055\\u308c\\u305f\\u6841\\u6570\\u306b\\u4e38\\u3081\\u308b\\n27:     return round(pi, digits)"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01UvezsUK8A3DpoXgvweWn7r', input={'command': 'view', 'path': './text_editor/test.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01UvezsUK8A3DpoXgvweWn7r',
#     'content': '"1: import math\\n2: from main import calculate_pi\\n3: \\n4: \\n5: def test_calculate_pi():\\n6:     \\"\\"\\"\\n7:     calculate_pi\\u95a2\\u6570\\u3092\\u30c6\\u30b9\\u30c8\\u3059\\u308b\\n8:     \\"\\"\\"\\n9:     # \\u5186\\u5468\\u7387\\u3092\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b5\\u6841\\u307e\\u3067\\u8a08\\u7b97\\n10:     result = calculate_pi(5)\\n11:     \\n12:     # \\u5b9f\\u969b\\u306e\\u5186\\u5468\\u7387\\u306e\\u5024\\uff08math.pi\\u3092\\u4f7f\\u7528\\uff09\\n13:     actual_pi = round(math.pi, 5)\\n14:     \\n15:     print(\\"=== \\u5186\\u5468\\u7387\\u8a08\\u7b97\\u306e\\u30c6\\u30b9\\u30c8 ===\\")\\n16:     print(f\\"\\u8a08\\u7b97\\u7d50\\u679c: {result}\\")\\n17:     print(f\\"\\u5b9f\\u969b\\u306e\\u5024: {actual_pi}\\")\\n18:     print(f\\"math.pi : {math.pi}\\")\\n19:     \\n20:     # \\u8aa4\\u5dee\\u3092\\u78ba\\u8a8d\\n21:     error = abs(result - actual_pi)\\n22:     print(f\\"\\u8aa4\\u5dee: {error}\\")\\n23:     \\n24:     # \\u30c6\\u30b9\\u30c8\\u7d50\\u679c\\n25:     if result == actual_pi:\\n26:         print(\\"\\u2713 \\u30c6\\u30b9\\u30c8\\u6210\\u529f: \\u8a08\\u7b97\\u7d50\\u679c\\u304c\\u6b63\\u3057\\u3044\\u3067\\u3059\\uff01\\")\\n27:         return True\\n28:     else:\\n29:         print(f\\"\\u2717 \\u30c6\\u30b9\\u30c8\\u5931\\u6557: \\u8a08\\u7b97\\u7d50\\u679c\\u304c\\u671f\\u5f85\\u5024\\u3068\\u7570\\u306a\\u308a\\u307e\\u3059\\")\\n30:         print(f\\"  \\u671f\\u5f85\\u5024: {actual_pi}\\")\\n31:         print(f\\"  \\u5b9f\\u969b: {result}\\")\\n32:         return False\\n33: \\n34: \\n35: def test_different_digits():\\n36:     \\"\\"\\"\\n37:     \\u7570\\u306a\\u308b\\u6841\\u6570\\u3067\\u30c6\\u30b9\\u30c8\\u3059\\u308b\\n38:     \\"\\"\\"\\n39:     print(\\"\\\\n=== \\u7570\\u306a\\u308b\\u6841\\u6570\\u3067\\u306e\\u30c6\\u30b9\\u30c8 ===\\")\\n40:     \\n41:     for digits in [1, 2, 3, 4, 5]:\\n42:         result = calculate_pi(digits)\\n43:         actual = round(math.pi, digits)\\n44:         match = \\"\\u2713\\" if result == actual else \\"\\u2717\\"\\n45:         print(f\\"{match} {digits}\\u6841: \\u8a08\\u7b97\\u7d50\\u679c={result}, \\u5b9f\\u969b={actual}\\")\\n46: \\n47: \\n48: if __name__ == \\"__main__\\":\\n49:     # \\u30c6\\u30b9\\u30c8\\u3092\\u5b9f\\u884c\\n50:     test_calculate_pi()\\n51:     test_different_digits()\\n52:     \\n53:     print(\\"\\\\n=== \\u8ffd\\u52a0\\u60c5\\u5831 ===\\")\\n54:     print(f\\"\\u5186\\u5468\\u7387\\uff08\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b5\\u6841\\uff09: {calculate_pi(5)}\\")\\n55: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='完璧です！以下の作業が完了しました：\n\n## 📝 作成内容\n\n### 1. **./text_editor/main.py** に `calculate_pi()` 関数を追加\n   - **機能**: 円周率を小数点以下5桁まで計算する関数\n   - **アルゴリズム**: ライプニッツの公式を使用（π = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)）\n   - **パラメータ**: `digits` (デフォルト: 5) - 小数点以下の桁数を指定可能\n   - **戻り値**: 指定された桁数に丸められた円周率の値\n\n### 2. **./text_editor/test.py** を作成\n   テストファイルには以下の機能を実装：\n   - **test_calculate_pi()**: 小数点以下5桁での計算結果を `math.pi` と比較\n   - **test_different_digits()**: 1〜5桁まで各桁数でテストを実施\n   - 計算結果、実際の値、誤差を表示\n   - テスト結果を視覚的に表示（✓ 成功 / ✗ 失敗）\n\nテストを実行するには、`./text_editor` ディレクトリで以下のコマンドを実行してください：\n```bash\npython test.py\n```\n\n円周率は約3.14159となり、小数点以下5桁では **3.14159** が期待される結果です！', type='text')]}]

# %%
messages = []

add_user_message(
    messages,
    """
    ./text_editorの下にあるmain.pyとtest.pyを開いて内容を確認してください。
    その後、main.pyとtest.pyの内容を説明するREADMEを ./text_editor/README.md として作成してください。
    """,
)

run_conversation(messages)
# Out:
# ./text_editorディレクトリの内容を確認してから、main.pyとtest.pyを開いて確認します。
#
# 内容を確認しました。それでは、README.mdを作成します。
# 完了しました！
#
# ## 内容の説明
#
# ### **main.py**
# - **`greeting()`**: "Hi there"と表示するシンプルな挨拶関数
# - **`calculate_pi(digits=5)`**: ライプニッツの公式（π = 4 * (1 - 1/3 + 1/5 - 1/7 + ...)）を使用して円周率を計算する関数。100万回の反復で精度を高め、指定された桁数に丸めて返します。
#
# ### **test.py**
# - **`test_calculate_pi()`**: 円周率計算の基本テスト。小数点以下5桁で計算し、`math.pi`と比較して誤差を表示します。
# - **`test_different_digits()`**: 1桁から5桁までの異なる桁数で円周率を計算し、各テスト結果を表示します。
#
# ### **作成したREADME.md**
# 上記の2つのファイルの詳細な説明を含むドキュメントを作成しました。内容には以下が含まれます：
# - プロジェクト概要
# - ファイル構成
# - 各関数の詳細説明
# - 使用方法とコード例
# - テストの実行方法
# - 注意事項と依存関係
# [{'role': 'user',
#   'content': '\n    ./text_editorの下にあるmain.pyとtest.pyを開いて内容を確認してください。\n    その後、main.pyとtest.pyの内容を説明するREADMEを ./text_editor/README.md として作成してください。\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='./text_editorディレクトリの内容を確認してから、main.pyとtest.pyを開いて確認します。', type='text'),
#    ToolUseBlock(id='toolu_01GDVpaZEhjfiAzFLVhLLyV5', input={'command': 'view', 'path': './text_editor'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01GDVpaZEhjfiAzFLVhLLyV5',
#     'content': '"__pycache__\\ntest.py\\nmain.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_01Mc2grMZJvk5UKfKZ7KkQbv', input={'command': 'view', 'path': './text_editor/main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'}),
#    ToolUseBlock(id='toolu_015UT1oMgyJHgopFAtcvX61E', input={'command': 'view', 'path': './text_editor/test.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01Mc2grMZJvk5UKfKZ7KkQbv',
#     'content': '"1: def greeting():\\n2:     print(\\"Hi there\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     \\u5186\\u5468\\u7387\\u3092\\u6307\\u5b9a\\u3055\\u308c\\u305f\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u306e\\u6841\\u6570\\u307e\\u3067\\u8a08\\u7b97\\u3059\\u308b\\u95a2\\u6570\\n8:     \\u30e9\\u30a4\\u30d7\\u30cb\\u30c3\\u30c4\\u306e\\u516c\\u5f0f\\u3092\\u4f7f\\u7528: \\u03c0 = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\\n9:     \\n10:     Parameters:\\n11:     digits (int): \\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u306e\\u6841\\u6570\\uff08\\u30c7\\u30d5\\u30a9\\u30eb\\u30c8: 5\\uff09\\n12:     \\n13:     Returns:\\n14:     float: \\u8a08\\u7b97\\u3055\\u308c\\u305f\\u5186\\u5468\\u7387\\u306e\\u5024\\u3092\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b\\u6307\\u5b9a\\u6841\\u6570\\u306b\\u4e38\\u3081\\u305f\\u5024\\n15:     \\"\\"\\"\\n16:     pi = 0.0\\n17:     # \\u7cbe\\u5ea6\\u3092\\u9ad8\\u3081\\u308b\\u305f\\u3081\\u306b\\u5341\\u5206\\u306a\\u53cd\\u5fa9\\u56de\\u6570\\u3092\\u8a2d\\u5b9a\\n18:     iterations = 1000000\\n19:     \\n20:     for i in range(iterations):\\n21:         # \\u30e9\\u30a4\\u30d7\\u30cb\\u30c3\\u30c4\\u306e\\u516c\\u5f0f\\n22:         pi += ((-1) ** i) / (2 * i + 1)\\n23:     \\n24:     pi *= 4\\n25:     \\n26:     # \\u6307\\u5b9a\\u3055\\u308c\\u305f\\u6841\\u6570\\u306b\\u4e38\\u3081\\u308b\\n27:     return round(pi, digits)"',
#     'is_error': False},
#    {'type': 'tool_result',
#     'tool_use_id': 'toolu_015UT1oMgyJHgopFAtcvX61E',
#     'content': '"1: import math\\n2: from main import calculate_pi\\n3: \\n4: \\n5: def test_calculate_pi():\\n6:     \\"\\"\\"\\n7:     calculate_pi\\u95a2\\u6570\\u3092\\u30c6\\u30b9\\u30c8\\u3059\\u308b\\n8:     \\"\\"\\"\\n9:     # \\u5186\\u5468\\u7387\\u3092\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b5\\u6841\\u307e\\u3067\\u8a08\\u7b97\\n10:     result = calculate_pi(5)\\n11:     \\n12:     # \\u5b9f\\u969b\\u306e\\u5186\\u5468\\u7387\\u306e\\u5024\\uff08math.pi\\u3092\\u4f7f\\u7528\\uff09\\n13:     actual_pi = round(math.pi, 5)\\n14:     \\n15:     print(\\"=== \\u5186\\u5468\\u7387\\u8a08\\u7b97\\u306e\\u30c6\\u30b9\\u30c8 ===\\")\\n16:     print(f\\"\\u8a08\\u7b97\\u7d50\\u679c: {result}\\")\\n17:     print(f\\"\\u5b9f\\u969b\\u306e\\u5024: {actual_pi}\\")\\n18:     print(f\\"math.pi : {math.pi}\\")\\n19:     \\n20:     # \\u8aa4\\u5dee\\u3092\\u78ba\\u8a8d\\n21:     error = abs(result - actual_pi)\\n22:     print(f\\"\\u8aa4\\u5dee: {error}\\")\\n23:     \\n24:     # \\u30c6\\u30b9\\u30c8\\u7d50\\u679c\\n25:     if result == actual_pi:\\n26:         print(\\"\\u2713 \\u30c6\\u30b9\\u30c8\\u6210\\u529f: \\u8a08\\u7b97\\u7d50\\u679c\\u304c\\u6b63\\u3057\\u3044\\u3067\\u3059\\uff01\\")\\n27:         return True\\n28:     else:\\n29:         print(f\\"\\u2717 \\u30c6\\u30b9\\u30c8\\u5931\\u6557: \\u8a08\\u7b97\\u7d50\\u679c\\u304c\\u671f\\u5f85\\u5024\\u3068\\u7570\\u306a\\u308a\\u307e\\u3059\\")\\n30:         print(f\\"  \\u671f\\u5f85\\u5024: {actual_pi}\\")\\n31:         print(f\\"  \\u5b9f\\u969b: {result}\\")\\n32:         return False\\n33: \\n34: \\n35: def test_different_digits():\\n36:     \\"\\"\\"\\n37:     \\u7570\\u306a\\u308b\\u6841\\u6570\\u3067\\u30c6\\u30b9\\u30c8\\u3059\\u308b\\n38:     \\"\\"\\"\\n39:     print(\\"\\\\n=== \\u7570\\u306a\\u308b\\u6841\\u6570\\u3067\\u306e\\u30c6\\u30b9\\u30c8 ===\\")\\n40:     \\n41:     for digits in [1, 2, 3, 4, 5]:\\n42:         result = calculate_pi(digits)\\n43:         actual = round(math.pi, digits)\\n44:         match = \\"\\u2713\\" if result == actual else \\"\\u2717\\"\\n45:         print(f\\"{match} {digits}\\u6841: \\u8a08\\u7b97\\u7d50\\u679c={result}, \\u5b9f\\u969b={actual}\\")\\n46: \\n47: \\n48: if __name__ == \\"__main__\\":\\n49:     # \\u30c6\\u30b9\\u30c8\\u3092\\u5b9f\\u884c\\n50:     test_calculate_pi()\\n51:     test_different_digits()\\n52:     \\n53:     print(\\"\\\\n=== \\u8ffd\\u52a0\\u60c5\\u5831 ===\\")\\n54:     print(f\\"\\u5186\\u5468\\u7387\\uff08\\u5c0f\\u6570\\u70b9\\u4ee5\\u4e0b5\\u6841\\uff09: {calculate_pi(5)}\\")\\n55: "',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='内容を確認しました。それでは、README.mdを作成します。', type='text'),
#    ToolUseBlock(id='toolu_01SnT4UHb6eKj1FGAXoY6Si2', input={'command': 'create', 'path': './text_editor/README.md', 'file_text': '# Text Editor プロジェクト\n\nこのプロジェクトは、円周率（π）を計算するPythonモジュールとそのテストコードで構成されています。\n\n## ファイル構成\n\n- `main.py`: 円周率計算のメイン機能を提供\n- `test.py`: main.pyの関数をテストするテストコード\n\n## main.py\n\n### 関数一覧\n\n#### `greeting()`\n簡単な挨拶メッセージ "Hi there" を出力する関数です。\n\n#### `calculate_pi(digits=5)`\nライプニッツの公式を使用して円周率を計算する関数です。\n\n**ライプニッツの公式:**\n```\nπ = 4 * (1 - 1/3 + 1/5 - 1/7 + 1/9 - ...)\n```\n\n**パラメータ:**\n- `digits` (int): 小数点以下の桁数（デフォルト: 5）\n\n**戻り値:**\n- float: 計算された円周率の値を指定された桁数に丸めた値\n\n**実装の詳細:**\n- 反復回数: 1,000,000回（精度を高めるため）\n- 計算方法: ライプニッツの公式を用いた級数展開\n- 結果は指定された桁数に四捨五入されます\n\n## test.py\n\n円周率計算関数のテストを実行するモジュールです。\n\n### テスト関数一覧\n\n#### `test_calculate_pi()`\n`calculate_pi()`関数の基本的なテストを実行します。\n\n**テスト内容:**\n- 小数点以下5桁で円周率を計算\n- `math.pi`の値と比較\n- 誤差を計算して表示\n- 計算結果が正しいかを検証\n\n**出力:**\n- 計算結果\n- 実際の値（math.pi）\n- 誤差\n- テスト成功/失敗の判定\n\n#### `test_different_digits()`\n異なる桁数（1〜5桁）で円周率計算をテストします。\n\n**テスト内容:**\n- 1桁、2桁、3桁、4桁、5桁の各桁数で計算を実行\n- 各桁数での計算結果と期待値を比較\n- 各テストの成功/失敗を表示\n\n## 使用方法\n\n### main.pyの使用例\n\n```python\nfrom main import calculate_pi, greeting\n\n# 挨拶を表示\ngreeting()\n\n# 円周率を計算（デフォルト: 小数点以下5桁）\npi = calculate_pi()\nprint(f"π = {pi}")\n\n# 異なる桁数で計算\npi_3 = calculate_pi(3)\nprint(f"π (3桁) = {pi_3}")\n```\n\n### テストの実行\n\n```bash\npython test.py\n```\n\n**実行すると表示される内容:**\n1. 基本的な円周率計算のテスト結果\n2. 異なる桁数でのテスト結果（1〜5桁）\n3. 追加情報（小数点以下5桁の円周率）\n\n## 注意事項\n\n- ライプニッツの公式は収束が遅いため、高精度な計算には多くの反復が必要です\n- 現在の実装では1,000,000回の反復により、小数点以下5桁程度の精度が得られます\n- より高い精度が必要な場合は、反復回数を増やすか、他のアルゴリズム（例: マチンの公式）の使用を検討してください\n\n## 依存関係\n\n- Python 3.x\n- 標準ライブラリ: `math`\n\n## ライセンス\n\nこのプロジェクトの詳細なライセンス情報は含まれていません。\n'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01SnT4UHb6eKj1FGAXoY6Si2',
#     'content': '"Successfully created ./text_editor/README.md"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='完了しました！\n\n## 内容の説明\n\n### **main.py**\n- **`greeting()`**: "Hi there"と表示するシンプルな挨拶関数\n- **`calculate_pi(digits=5)`**: ライプニッツの公式（π = 4 * (1 - 1/3 + 1/5 - 1/7 + ...)）を使用して円周率を計算する関数。100万回の反復で精度を高め、指定された桁数に丸めて返します。\n\n### **test.py**\n- **`test_calculate_pi()`**: 円周率計算の基本テスト。小数点以下5桁で計算し、`math.pi`と比較して誤差を表示します。\n- **`test_different_digits()`**: 1桁から5桁までの異なる桁数で円周率を計算し、各テスト結果を表示します。\n\n### **作成したREADME.md**\n上記の2つのファイルの詳細な説明を含むドキュメントを作成しました。内容には以下が含まれます：\n- プロジェクト概要\n- ファイル構成\n- 各関数の詳細説明\n- 使用方法とコード例\n- テストの実行方法\n- 注意事項と依存関係', type='text')]}]
