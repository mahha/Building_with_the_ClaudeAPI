# %% [markdown]
# ### "Chat Excercise" : 会話履歴を持つChatBot

# %%
#Install dependencies
# %uv pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %% [markdown]
# ### 履歴付きの会話

# %%
def add_user_message(message, text):
    user_message = {
        "role": "user",
        "content": text
    }
    message.append(user_message)

def add_assistant_message(message, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    message.append(assistant_message)

# Make a request
def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages
    )
    return message.content[0].text

# %% [markdown]
# ### ミニチャットボット

# %%
# Make an initial list of messages
messages = []

# Use a 'while True' loop to run the chatbot forever
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # Add the user message to the conversation history
    add_user_message(messages, user_input)
    # Call Claude with the 'chat' function
    answer = chat(messages)
    # Add Claude's response to the conversation history
    add_assistant_message(messages, answer)
    # Print Claude's response
    print ("--- Claude ---")
    print(messages[-1]['content'])
    print ("---")
# Out:
# > What's 1+2
# --- Claude ---
# 1 + 2 = 3
# ---
# > Multiply by 4
# --- Claude ---
# 3 × 4 = 12
# ---
# > by the way, What's 1kg + 1hour
# --- Claude ---
# You can't directly add 1 kg + 1 hour because they represent different types of quantities:
#
# - 1 kg is a unit of mass
# - 1 hour is a unit of time
#
# Adding quantities with different dimensions (mass + time) doesn't have a meaningful result in standard mathematics or physics. It's like asking "What's 1 apple + 1 idea?" - the units are incompatible for addition.
#
# If you have a specific context or application in mind, I'd be happy to help think through what calculation might actually be useful!
# ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       4 # Use a 'while True' loop to run the chatbot forever
#       5 while True:
#       6     # Get user input
# ----> 7     user_input = input("> ")
#       8     print(">", user_input)
#      10     # Add the user message to the conversation history
#
# File ~/Project/Python/Building_with_the_ClaudeAPI/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# File ~/Project/Python/Building_with_the_ClaudeAPI/.venv/lib/python3.13/site-packages/ipykernel/kernelbase.py:1441, in Kernel._input_request(self, prompt, ident, parent, password)
#    1438 except KeyboardInterrupt:
#    1439     # re-raise KeyboardInterrupt, to truncate traceback
#    1440     msg = "Interrupted by user"
# -> 1441     raise KeyboardInterrupt(msg) from None
#    1442 except Exception:
#    1443     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
