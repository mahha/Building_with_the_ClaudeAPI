# %% [markdown]
# ### "Temperature" : 会話のバラツキ
# - temperature が0に近いほど固定、1に近いほどランダムになる

# %%
#Install dependencies
# %uv pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %% [markdown]
# ### Temperature対応の関数

# %%
def add_user_message(message, text):
    user_message = {
        "role": "user",
        "content": text
    }
    message.append(user_message)

def add_assistant_message(message, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    message.append(assistant_message)

# Make a request
def chat(messages, system=None,temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %% [markdown]
# ### Temperature=0の会話

# %%
# Make an initial list of messages
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea. answer with Japanese"
)
print(messages[-1]['content'])

answer = chat(messages,temperature=0.0)
print("1回目の回答",answer)

answer = chat(messages,temperature=0.0)
print("2回目の回答",answer)
# Out:
# Generate a one sentence movie idea. answer with Japanese
# 1回目の回答 宇宙船の故障で未知の惑星に不時着した宇宙飛行士が、その星の知的生命体と心を通わせながら地球帰還を目指す物語。
# 2回目の回答 宇宙船の故障で未知の惑星に不時着した宇宙飛行士が、その星の知的生命体と心を通わせながら地球帰還を目指す物語。

# %% [markdown]
# ### Temperature1の会話

# %%
# Make an initial list of messages
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea. answer with Japanese"
)
print(messages[-1]['content'])

answer = chat(messages,temperature=1.0)
print("1回目の回答",answer)

answer = chat(messages,temperature=1.0)
print("2回目の回答",answer)
# Out:
# Generate a one sentence movie idea. answer with Japanese
# 1回目の回答 宇宙ステーションで謎の生命体に感染した宇宙飛行士が、地球帰還を目指しながら自分の人間性を保とうと必死に闘う物語。
# 2回目の回答 宇宙船の中で目覚めた記憶喪失の主人公が、実は地球最後の生存者を運ぶ重要なミッションの責任者だったことを発見する物語。
