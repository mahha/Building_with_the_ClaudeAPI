# %% [markdown]
# ### "System prompts" : 役割を与えたChatbot

# %%
#Install dependencies
# %uv pip install anthropic python-dotenv

# %%
# Load env variables
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-0"

# %% [markdown]
# ### 履歴付きの会話

# %%
def add_user_message(message, text):
    user_message = {
        "role": "user",
        "content": text
    }
    message.append(user_message)

def add_assistant_message(message, text):
    assistant_message = {
        "role": "assistant",
        "content": text
    }
    message.append(assistant_message)

# Make a request
def chat(messages, system=None,temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %% [markdown]
# ### ミニチャットボット

# %%
# Make an initial list of messages
messages = []

add_user_message(
    messages, 
    "Generate a one sentence movie idea. answer with Japanese"
)
print(messages[-1]['content'])

answer = chat(messages,temperature=0.0)
print(answer)
# Out:
# Generate a one sentence movie idea. answer with Japanese
# 宇宙船の故障で未知の惑星に不時着した宇宙飛行士が、その星の知的生命体と心を通わせながら地球帰還を目指す物語。

# %%
# Make an initial list of messages
messages = []

add_user_message(
    messages,
    "Generate a one sentence movie idea. answer with Japanese"
)
print(messages[-1]['content'])

answer = chat(messages,temperature=1.0)
print(answer)
# Out:
# Generate a one sentence movie idea. answer with Japanese
# 未来の日本で、記憶を売買できる技術が発明され、貧しい青年が自分の幸せな記憶を富豪に売って家族を救おうとする物語。
